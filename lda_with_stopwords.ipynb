# %% [markdown]
# # Darks Souls II Reviews (2025)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import altair as alt
import re

# %% [markdown]
# ## Steam Reviews as of 3/30/24:

# %%
df = pd.read_csv('reviews.csv')
reviews = df.copy()
reviews = reviews.set_index('recommendationid')
reviews.drop(columns={'Unnamed: 0', 'in_early_access'}, inplace=True)

# %% [markdown]
# Converting date of review from unix:

# %%
reviews['month_name'] = pd.to_datetime(reviews.update_date, unit='s').dt.month_name()
reviews['month']      = pd.to_datetime(reviews.update_date, unit='s').dt.month
reviews['year']       = pd.to_datetime(reviews.update_date, unit='s').dt.year
reviews['day']        = pd.to_datetime(reviews.update_date, unit='s').dt.day
# Out:
# C:\Users\bdion\AppData\Local\Temp\ipykernel_13528\2518063978.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reviews['month_name'] = pd.to_datetime(reviews.update_date, unit='s').dt.month_name()
# C:\Users\bdion\AppData\Local\Temp\ipykernel_13528\2518063978.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reviews['month'] = pd.to_datetime(reviews.update_date, unit='s').dt.month
# C:\Users\bdion\AppData\Local\Temp\ipykernel_13528\2518063978.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reviews['year'] = pd.to_datetime(reviews.update_date, unit='s').dt.year
# C:\Users\bdion\AppData\Local\Temp\ipykernel_13528\2518063978.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reviews['day'] = pd.to_datetime(reviews.update_date, unit='s').dt.day

# %% [markdown]
# Focusing on just the English reviews:

# %%
reviews = reviews[reviews.language == 'english']

# %% [markdown]
# ## Cleaning up the reviews

# %%
reviews['review'] = reviews.review.str.lower()

# %%
from nltk.corpus import stopwords

# Removing urls:
r = [re.sub(r'http\S+', '', review).lower().strip() if pd.notna(review) else review for review in reviews.review]

# Removing esc sequences, punctuation, and numbers:
    # There's some ASCII art in some of the reviews
r = [re.sub(r'[^A-Za-z]', ' ', review).strip() if pd.notna(review) else review for review in r]

# Removing multiple and trailing whitespaces:
r = [re.sub(r' +', ' ', review).strip() if pd.notna(review) else review for review in r]

reviews['review'] = r

# %%
reviews
# Out:
#                                                              review language  \
# recommendationid
# 190511148                                     dont give up skeleton  english
# 190504311                                                      boia  english
# 190502415         i love this game to pieces it s the worst soul...  english
# 190501465         i probably shouldn t recommend it because of h...  english
# 190500200                                                peak souls  english
# ...                                                             ...      ...
# 15162268                                        try tongue but hole  english
# 15162220          so far so good played it for mins so far with ...  english
# 15162161          still haven t died bonedrinker rufus keep the ...  english
# 15162057                                        needs more cow bell  english
# 15161857                                            would die again  english
#
#                    init_date  update_date  voted_up  month  year
# recommendationid
# 190511148         1742267451   1742267451      True  March  2025
# 190504311         1742259081   1742259081      True  March  2025
# 190502415         1742256864   1742256864      True  March  2025
# 190501465         1742255757   1742255757      True  March  2025
# 190500200         1742254339   1742254339      True  March  2025
# ...                      ...          ...       ...    ...   ...
# 15162268          1427932431   1428081346      True  April  2015
# 15162220          1427932153   1427932153      True  April  2015
# 15162161          1427931845   1427931845      True  April  2015
# 15162057          1427931196   1427931196      True  April  2015
# 15161857          1427929899   1427929899      True  April  2015
#
# [45674 rows x 7 columns]

# %% [markdown]
# ## Sentiment Analysis:
# - Seeing why people were positive or negative about the game
#     - Comments on story, gameplay, etc

# %% [markdown]
# For sake of analysis specifically on the actual reviews, drop any rows that have no reviews:

# %%
reviews = reviews.dropna(subset=['review'])
reviews.shape
# Out:
# (45563, 7)

# %% [markdown]
# Top 10 Most Common Words in the Reviews:

# %%
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
tfidf = TfidfVectorizer(sublinear_tf=True,
                        analyzer='word',
                        max_features=4000,
                        tokenizer=word_tokenize,
                        stop_words=stopwords.words("english"))

# %%
review_txt = reviews.review.values.flatten()
tfidf_array = tfidf.fit_transform(review_txt).toarray()
tfidf_df = pd.DataFrame(tfidf_array)
tfidf_df.columns = tfidf.get_feature_names_out()
# Out:
# c:\Users\bdion\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# c:\Users\bdion\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:408: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ["'d", "'ll", "'re", "'s", "'ve", 'could', 'might', 'must', "n't", 'need', 'sha', 'wo', 'would'] not in stop_words.
#   warnings.warn(

# %% [markdown]
# - Most common word among the reviews isn't very informative - including some of the other popular words
#     - Looking at subsets of the reviews could be useful

# %% [markdown]
# ### Topic Modeling:
# - Exploring certain aspects on why people like the game
#     - Also get critiques of the game in positive reviews (if any but there sure is considering DS2's reputation in the community)
#
# - Exploring why people don't like the game:
#     - Also get positive aspects within this subset of the reviews
#
# - Algorithms I can use to perform topic modeling:
#     1. Latent Dirichlet Allocation (LDA)
#     2. Non-negative Matrix Factorization (NMF)

# %% [markdown]
# Splitting the reviews by how many do and don't recommend buying the game:

# %%
pos_reviews = reviews[reviews['voted_up'] == True]
neg_reviews = reviews[reviews['voted_up'] == False]

# %%
pos_reviews.shape, neg_reviews.shape
# Out:
# ((37387, 7), (8176, 7))

# %% [markdown]
# Function to display the output of the models:

# %%
def display_topics(model, feature_names, no_top_words):
    topic_dict = {}
    for topic_idx, topic in enumerate(model.components_):
        topic_dict["Topic %d words" % (topic_idx + 1)]= ['{}'.format(feature_names[i])
                        for i in topic.argsort()[:-no_top_words - 1:-1]]
        topic_dict["Topic %d weights" % (topic_idx + 1)]= ['{:.1f}'.format(topic[i])
                        for i in topic.argsort()[:-no_top_words - 1:-1]]
    return pd.DataFrame(topic_dict)

# %% [markdown]
# LDA: Probabilistic graphical modeling, and uses CountVectorizer as input

# %%
from sklearn.decomposition import LatentDirichletAllocation

# %%
count_vector = CountVectorizer()

tf = count_vector.fit_transform(reviews.review)
tf_feat_names = count_vector.get_feature_names_out()

pos_tf = count_vector.fit_transform(pos_reviews.review) 
pos_tf_feat_names = count_vector.get_feature_names_out()

neg_tf = count_vector.fit_transform(neg_reviews.review)
neg_tf_feat_names = count_vector.get_feature_names_out()

# %%
lda = LatentDirichletAllocation(n_components=3, random_state=42069)
lda.fit(tf)
# Out:
# LatentDirichletAllocation(n_components=3, random_state=42069)

# %%
no_top_words = 10
display_topics(lda, tf_feat_names, no_top_words)
# Out:
#   Topic 1 words Topic 1 weights Topic 2 words Topic 2 weights Topic 3 words  \
# 0         souls          6058.9           the        116528.4          game
# 1          dark          4617.4           and         58230.1          this
# 2           the          2977.7            to         51953.0            it
# 3          best          2909.3            of         50020.8           you
# 4            of          1579.7            it         42364.5           and
# 5          keep          1546.8          game         38244.9           the
# 6          hate          1448.9           you         37730.2            to
# 7          iron          1409.7            is         36991.0            is
# 8            ii          1186.0            in         31495.6          good
# 9       scholar          1011.1         souls         27086.8            my
#
#   Topic 3 weights
# 0         19391.9
# 1         13047.2
# 2         11285.6
# 3          9087.7
# 4          8744.9
# 5          8636.9
# 6          8483.3
# 7          7518.9
# 8          5802.5
# 9          4755.7

# %% [markdown]
# - Interpreted topics that were identified:
#     1. People saying how good the game is
#     2. Bosses/enemies
#     3. People expressing their likes or dislikes of the game

# %%
pos_lda = LatentDirichletAllocation(n_components=3, random_state=42069)
pos_lda.fit(pos_tf)
# Out:
# LatentDirichletAllocation(n_components=3, random_state=42069)

# %%
display_topics(pos_lda, pos_tf_feat_names, no_top_words)
# Out:
#   Topic 1 words Topic 1 weights Topic 2 words Topic 2 weights Topic 3 words  \
# 0          game          3593.1           the         30013.8           the
# 1          good          1928.2            it         23354.0           and
# 2          this          1393.9          game         22980.7            to
# 3          love          1085.0         souls         17288.7            of
# 4           you          1057.6          this         14294.6           you
# 5          best          1011.0           and         13895.2            is
# 6           die           999.6            is         13270.1            in
# 7           gud           902.4          dark         12090.4            it
# 8         souls           856.1            of         11997.4          game
# 9          died           810.6           but         10458.6          that
#
#   Topic 3 weights
# 0         62263.0
# 1         34203.6
# 2         31791.2
# 3         27665.7
# 4         24623.5
# 5         18550.4
# 6         18204.5
# 7         16716.3
# 8         15781.2
# 9         14376.1

# %% [markdown]
# - Interpreted topics that were identified:
#     1. People expressing that they loved the game (expected since I'm looking at the subset of reviews that recommend the game)
#     2. (similar to 1st topic)
#     3. Bosses/enemies

# %%
neg_lda = LatentDirichletAllocation(n_components=3, random_state=42069)
neg_lda.fit(neg_tf)
# Out:
# LatentDirichletAllocation(n_components=3, random_state=42069)

# %%
display_topics(neg_lda, neg_tf_feat_names, no_top_words)
# Out:
#   Topic 1 words Topic 1 weights Topic 2 words Topic 2 weights Topic 3 words  \
# 0           the         22002.4          game          4214.4           the
# 1            to         13441.0           the          3650.0          game
# 2           you         11680.2          this          3568.2           and
# 3           and         11648.9            it          2675.9            it
# 4            of         10080.3            to          2360.9            of
# 5            is          7374.6           and          2211.3            to
# 6            in          7020.6            is          2033.2          this
# 7            it          6956.2           you          1823.6            is
# 8          game          6776.6         souls          1713.2         souls
# 9          that          6142.6          dark          1352.7            in
#
#   Topic 3 weights
# 0         10185.6
# 1          5093.0
# 2          4993.8
# 3          3950.8
# 4          3659.4
# 5          3415.1
# 6          3194.7
# 7          3077.1
# 8          2797.3
# 9          1813.9

# %% [markdown]
# - Interpreted topics that were identified:
#     1. Bosses/enemies
#     2. Controls/PC port of the game
#     3. Players' comments on that it's the worst Dark Souls game they've played

# %% [markdown]
# NMF: Linear algebra and uses the TF-IDF vectorizer as input

# %%
from sklearn.decomposition import NMF

# %%
nmf = NMF(n_components=3, random_state=42069)
nmf.fit(tfidf_array)
# Out:
# NMF(n_components=3, random_state=42069)

# %%
display_topics(nmf, tfidf.get_feature_names_out(), no_top_words)
# Out:
#   Topic 1 words Topic 1 weights Topic 2 words Topic 2 weights Topic 3 words  \
# 0         souls             4.6          good             5.3          game
# 1          dark             3.7          game             0.6         great
# 2          best             2.7        pretty             0.3            ds
# 3            ii             0.4         still             0.1           fun
# 4         games             0.3        really             0.0          like
# 5        series             0.3         souls             0.0          play
# 6        better             0.3      actually             0.0           bad
# 7         still             0.3          yeah             0.0         still
# 8         worst             0.2          luck             0.0           one
# 9          ever             0.2           get             0.0         first
#
#   Topic 3 weights
# 0             3.4
# 1             1.0
# 2             0.9
# 3             0.8
# 4             0.8
# 5             0.7
# 6             0.6
# 7             0.6
# 8             0.5
# 9             0.5

# %% [markdown]
# - Interpreted topics that were identified:
#     1. Positive experiences from the game
#     2. (similar to 1st topic)
#     3. Mixed reception of the game (love and hate)

# %%
pos_txt = pos_reviews.review.values.flatten()
pos_tfidf_array = tfidf.fit_transform(pos_txt).toarray()
nmf.fit(pos_tfidf_array)
# Out:
# c:\Users\bdion\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# NMF(n_components=3, random_state=42069)

# %%
display_topics(nmf, tfidf.get_feature_names_out(), no_top_words)
# Out:
#   Topic 1 words Topic 1 weights Topic 2 words Topic 2 weights Topic 3 words  \
# 0         souls             4.4          good             5.1          game
# 1          dark             3.5          game             0.5         great
# 2          best             2.9        pretty             0.3           fun
# 3            ii             0.4         still             0.1            ds
# 4         games             0.3         souls             0.0          like
# 5        series             0.3        really             0.0         still
# 6          ever             0.3      actually             0.0          play
# 7           one             0.3          yeah             0.0          love
# 8         still             0.3           get             0.0          hate
# 9        better             0.3          dark             0.0         first
#
#   Topic 3 weights
# 0             3.5
# 1             1.1
# 2             0.8
# 3             0.7
# 4             0.6
# 5             0.6
# 6             0.5
# 7             0.5
# 8             0.5
# 9             0.5

# %% [markdown]
# - Interpreted topics that were identified:
#     1. Positive outloooks on the game
#     2. similar to 1st topic
#     3. People expressing their opinion on the game, ranging from good to bad

# %%
neg_txt = neg_reviews.review.values.flatten()
neg_tfidf_array = tfidf.fit_transform(neg_txt).toarray()
nmf.fit(neg_tfidf_array)
# Out:
# c:\Users\bdion\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# NMF(n_components=3, random_state=42069)

# %%
display_topics(nmf, tfidf.get_feature_names_out(), no_top_words)
# Out:
#   Topic 1 words Topic 1 weights Topic 2 words Topic 2 weights Topic 3 words  \
# 0          game             1.9           bad             3.3         souls
# 1            ds             0.8          game             0.6          dark
# 2          like             0.7        really             0.1         worst
# 3          play             0.7        design             0.0          play
# 4          good             0.6         kinda             0.0          like
# 5           one             0.6     genuinely             0.0       instead
# 6          shit             0.5          port             0.0            ii
# 7          even             0.5         souls             0.0         games
# 8           get             0.5       general             0.0        series
# 9       enemies             0.5      hitboxes             0.0           buy
#
#   Topic 3 weights
# 0             2.5
# 1             2.3
# 2             0.4
# 3             0.2
# 4             0.2
# 5             0.2
# 6             0.2
# 7             0.2
# 8             0.1
# 9             0.1

# %% [markdown]
# - Interpreted topics that were identified:
#     1. Vague but concerned w/ enemies
#     2. Very negative perspectives on the game
#     3. Negative experience regarding bosses, hitboxes, and game design

# %% [markdown]
# ## Looking at reviews after DLC release:

# %%
dlc_reviews = reviews[(reviews.year >= 2014) & (reviews.month >= 7) & (reviews.day >= 22)]
dlc_reviews = dlc_reviews[dlc_reviews.review.isna() == False]
dlc_reviews = dlc_reviews[dlc_reviews.review.str.contains(r'\bdlc\b')]
dlc_reviews
# Out:
#                                                              review language  \
# recommendationid
# 184244595         i like it even though people kind of hate this...  english
# 184165897         i started the game trying not to think about a...  english
# 183613472         unironically a masterpiece my favourite of the...  english
# 183467284         the game is really really overhated although t...  english
# 183432730         i genuinely don t understand the amount of hat...  english
# ...                                                             ...      ...
# 15664976          hollow good buy if you don t already own game ...  english
# 15470237          i m changing my review to currently reflect th...  english
# 15296462          from an avid but not crazy player of dark soul...  english
# 15244026          the pc community split is the main reason it s...  english
# 15188179          at the time of writing this review the amount ...  english
#
#                    init_date  update_date  voted_up  month  year month_name  \
# recommendationid
# 184244595         1735584348   1735584348      True     12  2024   December
# 184165897         1735515416   1735515416     False     12  2024   December
# 183613472         1735091925   1735091925      True     12  2024   December
